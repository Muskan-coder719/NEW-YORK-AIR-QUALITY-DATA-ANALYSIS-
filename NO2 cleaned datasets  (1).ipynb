# %%
import pandas as pd

# %%
df1=pd.read_csv('NO2 2019.csv')
df1.shape
df1.head()
# Out:
#          Date Source    Site ID  POC  Daily Max 1-hour NO2 Concentration  \
# 0  01/01/2019    AQS  360050110    1                                36.5
# 1  01/02/2019    AQS  360050110    1                                30.5
# 2  01/03/2019    AQS  360050110    1                                37.6
# 3  01/04/2019    AQS  360050110    1                                31.9
# 4  01/05/2019    AQS  360050110    1                                31.3
#
#   Units  Daily AQI Value Local Site Name  Daily Obs Count  Percent Complete  \
# 0   ppb               34           IS 52               24             100.0
# 1   ppb               28           IS 52               24             100.0
# 2   ppb               35           IS 52               20              83.0
# 3   ppb               29           IS 52               24             100.0
# 4   ppb               29           IS 52               24             100.0
#
#    ...  AQS Parameter Description Method Code  CBSA Code  \
# ...

# %%
#checking for duplicates.
df1=df1.drop_duplicates()
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2626 entries, 0 to 2625
# Data columns (total 21 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Date                                2626 non-null   object
#  1   Source                              2626 non-null   object
#  2   Site ID                             2626 non-null   int64
#  3   POC                                 2626 non-null   int64
#  4   Daily Max 1-hour NO2 Concentration  2626 non-null   float64
#  5   Units                               2626 non-null   object
#  6   Daily AQI Value                     2626 non-null   int64
#  7   Local Site Name                     2626 non-null   object
#  8   Daily Obs Count                     2626 non-null   int64
#  9   Percent Complete                    2626 non-null   float64
#  10  AQS Parameter Code                  2626 non-null   int64
# ...

# %%
#checking for missing values.
missing_values_2019 = df1.isna().sum()
print(missing_values_2019)
# Out:
# Date                                  0
# Source                                0
# Site ID                               0
# POC                                   0
# Daily Max 1-hour NO2 Concentration    0
# Units                                 0
# Daily AQI Value                       0
# Local Site Name                       0
# Daily Obs Count                       0
# Percent Complete                      0
# AQS Parameter Code                    0
# AQS Parameter Description             0
# Method Code                           0
# CBSA Code                             0
# CBSA Name                             0
# State FIPS Code                       0
# State                                 0
# County FIPS Code                      0
# County                                0
# Site Latitude                         0
# Site Longitude                        0
# dtype: int64

# %%
df2=pd.read_csv('NO 2020.csv')
print(df2.shape)
#checking for duplicates.
df2=df2.drop_duplicates()
df2.info()
# Out:
# (2362, 21)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2362 entries, 0 to 2361
# Data columns (total 21 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Date                                2362 non-null   object
#  1   Source                              2362 non-null   object
#  2   Site ID                             2362 non-null   int64
#  3   POC                                 2362 non-null   int64
#  4   Daily Max 1-hour NO2 Concentration  2362 non-null   float64
#  5   Units                               2362 non-null   object
#  6   Daily AQI Value                     2362 non-null   int64
#  7   Local Site Name                     2362 non-null   object
#  8   Daily Obs Count                     2362 non-null   int64
#  9   Percent Complete                    2362 non-null   float64
#  10  AQS Parameter Code                  2362 non-null   int64
# ...

# %%
df2.head()
# Out:
#          Date Source    Site ID  POC  Daily Max 1-hour NO2 Concentration  \
# 0  01/01/2020    AQS  360050110    1                                18.1
# 1  01/02/2020    AQS  360050110    1                                40.6
# 2  01/03/2020    AQS  360050110    1                                38.5
# 3  01/04/2020    AQS  360050110    1                                30.7
# 4  01/05/2020    AQS  360050110    1                                20.8
#
#   Units  Daily AQI Value Local Site Name  Daily Obs Count  Percent Complete  \
# 0   ppb               17           IS 52               24             100.0
# 1   ppb               38           IS 52               24             100.0
# 2   ppb               36           IS 52               21              88.0
# 3   ppb               28           IS 52               24             100.0
# 4   ppb               19           IS 52               24             100.0
#
#    ...  AQS Parameter Description Method Code  CBSA Code  \
# ...

# %%
descriptive_stats_2019=df1.describe()
print(descriptive_stats_2019)
# Out:
#             Site ID          POC  Daily Max 1-hour NO2 Concentration  \
# count  2.626000e+03  2626.000000                         2626.000000
# mean   3.604610e+08     1.252856                           23.083892
# std    3.344342e+05     0.664789                           12.465526
# min    3.600501e+08     1.000000                            1.100000
# 25%    3.600501e+08     1.000000                           13.100000
# 50%    3.602900e+08     1.000000                           21.100000
# 75%    3.608101e+08     1.000000                           31.500000
# max    3.610300e+08     3.000000                           67.200000
#
#        Daily AQI Value  Daily Obs Count  Percent Complete  AQS Parameter Code  \
# count      2626.000000      2626.000000       2626.000000              2626.0
# mean         21.335491        23.429170         97.630998             42602.0
# std          11.794808         1.466492          6.122540                 0.0
# ...

# %%
#checking for missing values.
missing_values_2020 = df2.isna().sum()
print(missing_values_2020)
# Out:
# Date                                  0
# Source                                0
# Site ID                               0
# POC                                   0
# Daily Max 1-hour NO2 Concentration    0
# Units                                 0
# Daily AQI Value                       0
# Local Site Name                       0
# Daily Obs Count                       0
# Percent Complete                      0
# AQS Parameter Code                    0
# AQS Parameter Description             0
# Method Code                           0
# CBSA Code                             0
# CBSA Name                             0
# State FIPS Code                       0
# State                                 0
# County FIPS Code                      0
# County                                0
# Site Latitude                         0
# Site Longitude                        0
# dtype: int64

# %%
NO2_descriptive_stats_2020=df2.describe()
print(NO2_descriptive_stats_2020)
# Out:
#             Site ID          POC  Daily Max 1-hour NO2 Concentration  \
# count  2.362000e+03  2362.000000                         2362.000000
# mean   3.604048e+08     1.303980                           21.776291
# std    3.068500e+05     0.718174                           11.456810
# min    3.600501e+08     1.000000                            2.400000
# 25%    3.600501e+08     1.000000                           13.000000
# 50%    3.602900e+08     1.000000                           19.900000
# 75%    3.608101e+08     1.000000                           29.075000
# max    3.608101e+08     3.000000                           76.400000
#
#        Daily AQI Value  Daily Obs Count  Percent Complete  AQS Parameter Code  \
# count      2362.000000      2362.000000       2362.000000              2362.0
# mean         20.112616        23.456816         97.736240             42602.0
# std          10.850219         1.439165          6.024329                 0.0
# ...

# %%
df3=pd.read_csv('NO 2021.csv')
print(df3.shape)
#checking for duplicates.
df3=df3.drop_duplicates()
df3.info()
# Out:
# (2596, 21)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2596 entries, 0 to 2595
# Data columns (total 21 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Date                                2596 non-null   object
#  1   Source                              2596 non-null   object
#  2   Site ID                             2596 non-null   int64
#  3   POC                                 2596 non-null   int64
#  4   Daily Max 1-hour NO2 Concentration  2596 non-null   float64
#  5   Units                               2596 non-null   object
#  6   Daily AQI Value                     2596 non-null   int64
#  7   Local Site Name                     2596 non-null   object
#  8   Daily Obs Count                     2596 non-null   int64
#  9   Percent Complete                    2596 non-null   float64
#  10  AQS Parameter Code                  2596 non-null   int64
# ...

# %%
#checking for missing values.
missing_values_2021 = df3.isna().sum()
print(missing_values_2021)
# Out:
# Date                                  0
# Source                                0
# Site ID                               0
# POC                                   0
# Daily Max 1-hour NO2 Concentration    0
# Units                                 0
# Daily AQI Value                       0
# Local Site Name                       0
# Daily Obs Count                       0
# Percent Complete                      0
# AQS Parameter Code                    0
# AQS Parameter Description             0
# Method Code                           0
# CBSA Code                             0
# CBSA Name                             0
# State FIPS Code                       0
# State                                 0
# County FIPS Code                      0
# County                                0
# Site Latitude                         0
# Site Longitude                        0
# dtype: int64

# %%
descriptive_stats_2021=df3.describe()
print(descriptive_stats_2021)
# Out:
#             Site ID          POC  Daily Max 1-hour NO2 Concentration  \
# count  2.596000e+03  2596.000000                         2596.000000
# mean   3.604517e+08     1.267334                           21.401541
# std    3.302617e+05     0.680720                           11.298819
# min    3.600501e+08     1.000000                            1.000000
# 25%    3.600501e+08     1.000000                           12.675000
# 50%    3.602900e+08     1.000000                           19.500000
# 75%    3.608101e+08     1.000000                           29.100000
# max    3.610300e+08     3.000000                           77.400000
#
#        Daily AQI Value  Daily Obs Count  Percent Complete  AQS Parameter Code  \
# count      2596.000000      2596.000000       2596.000000              2596.0
# mean         19.758475        23.429892         97.637519             42602.0
# std          10.688505         1.430232          5.968314                 0.0
# ...

# %%
df4=pd.read_csv('NO 2022.csv')
print(df4.shape)
df4.info()
#checking for duplicates.
df4=df4.drop_duplicates()
# Out:
# (2750, 21)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2750 entries, 0 to 2749
# Data columns (total 21 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Date                                2750 non-null   object
#  1   Source                              2750 non-null   object
#  2   Site ID                             2750 non-null   int64
#  3   POC                                 2750 non-null   int64
#  4   Daily Max 1-hour NO2 Concentration  2750 non-null   float64
#  5   Units                               2750 non-null   object
#  6   Daily AQI Value                     2750 non-null   int64
#  7   Local Site Name                     2750 non-null   object
#  8   Daily Obs Count                     2750 non-null   int64
#  9   Percent Complete                    2750 non-null   float64
#  10  AQS Parameter Code                  2750 non-null   int64
# ...

# %%
#checking for missing values.
missing_values_2021 = df3.isna().sum()
print(missing_values_2021)
# Out:
# Date                                  0
# Source                                0
# Site ID                               0
# POC                                   0
# Daily Max 1-hour NO2 Concentration    0
# Units                                 0
# Daily AQI Value                       0
# Local Site Name                       0
# Daily Obs Count                       0
# Percent Complete                      0
# AQS Parameter Code                    0
# AQS Parameter Description             0
# Method Code                           0
# CBSA Code                             0
# CBSA Name                             0
# State FIPS Code                       0
# State                                 0
# County FIPS Code                      0
# County                                0
# Site Latitude                         0
# Site Longitude                        0
# dtype: int64

# %%
descriptive_stats_2022=df4.describe()
print(descriptive_stats_2022)
# Out:
#             Site ID          POC  Daily Max 1-hour NO2 Concentration  \
# count  2.750000e+03  2750.000000                         2750.000000
# mean   3.604765e+08     1.259636                           22.276618
# std    3.483930e+05     0.672329                           12.557429
# min    3.600501e+08     1.000000                            1.000000
# 25%    3.600501e+08     1.000000                           12.700000
# 50%    3.602900e+08     1.000000                           20.100000
# 75%    3.608101e+08     1.000000                           30.475000
# max    3.610300e+08     3.000000                           82.700000
#
#        Daily AQI Value  Daily Obs Count  Percent Complete  AQS Parameter Code  \
# count      2750.000000      2750.000000       2750.000000              2750.0
# mean         20.602909        23.420727         97.603636             42602.0
# std          11.873046         1.436699          5.988772                 0.0
# ...

# %%
df5=pd.read_csv('NO 2023.csv')
print(df5.shape)
df5.info()
#checking for duplicates.
df5=df5.drop_duplicates()
# Out:
# (2775, 21)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2775 entries, 0 to 2774
# Data columns (total 21 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Date                                2775 non-null   object
#  1   Source                              2775 non-null   object
#  2   Site ID                             2775 non-null   int64
#  3   POC                                 2775 non-null   int64
#  4   Daily Max 1-hour NO2 Concentration  2775 non-null   float64
#  5   Units                               2775 non-null   object
#  6   Daily AQI Value                     2775 non-null   int64
#  7   Local Site Name                     2775 non-null   object
#  8   Daily Obs Count                     2775 non-null   int64
#  9   Percent Complete                    2775 non-null   float64
#  10  AQS Parameter Code                  2775 non-null   int64
# ...

# %%
#checking for missing values.
missing_values_2023 = df5.isna().sum()
print(missing_values_2023)
# Out:
# Date                                  0
# Source                                0
# Site ID                               0
# POC                                   0
# Daily Max 1-hour NO2 Concentration    0
# Units                                 0
# Daily AQI Value                       0
# Local Site Name                       0
# Daily Obs Count                       0
# Percent Complete                      0
# AQS Parameter Code                    0
# AQS Parameter Description             0
# Method Code                           0
# CBSA Code                             0
# CBSA Name                             0
# State FIPS Code                       0
# State                                 0
# County FIPS Code                      0
# County                                0
# Site Latitude                         0
# Site Longitude                        0
# dtype: int64

# %%
descriptive_stats_2023=df5.describe()
print(descriptive_stats_2023)
# Out:
#             Site ID          POC  Daily Max 1-hour NO2 Concentration  \
# count  2.775000e+03  2775.000000                         2775.000000
# mean   3.604847e+08     1.243604                           21.722306
# std    3.490473e+05     0.654231                           12.571745
# min    3.600501e+08     1.000000                            0.800000
# 25%    3.600501e+08     1.000000                           11.900000
# 50%    3.602900e+08     1.000000                           19.900000
# 75%    3.608101e+08     1.000000                           29.600000
# max    3.610300e+08     3.000000                           78.800000
#
#        Daily AQI Value  Daily Obs Count  Percent Complete  AQS Parameter Code  \
# count      2775.000000      2775.000000       2775.000000              2775.0
# mean         20.064144        23.472793         97.827027             42602.0
# std          11.897856         1.303273          5.421890                 0.0
# ...

# %%
df6=pd.read_csv('NO 2024.csv')
print(df6.shape)
df6.info()
#checking for duplicates.
df6=df6.drop_duplicates()
# Out:
# (1390, 21)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1390 entries, 0 to 1389
# Data columns (total 21 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Date                                1390 non-null   object
#  1   Source                              1390 non-null   object
#  2   Site ID                             1390 non-null   int64
#  3   POC                                 1390 non-null   int64
#  4   Daily Max 1-hour NO2 Concentration  1390 non-null   float64
#  5   Units                               1390 non-null   object
#  6   Daily AQI Value                     1390 non-null   int64
#  7   Local Site Name                     1390 non-null   object
#  8   Daily Obs Count                     1390 non-null   int64
#  9   Percent Complete                    1390 non-null   float64
#  10  AQS Parameter Code                  1390 non-null   int64
# ...

# %%
#checking for missing values.
missing_values_2024 = df6.isna().sum()
print(missing_values_2024)
# Out:
# Date                                  0
# Source                                0
# Site ID                               0
# POC                                   0
# Daily Max 1-hour NO2 Concentration    0
# Units                                 0
# Daily AQI Value                       0
# Local Site Name                       0
# Daily Obs Count                       0
# Percent Complete                      0
# AQS Parameter Code                    0
# AQS Parameter Description             0
# Method Code                           0
# CBSA Code                             0
# CBSA Name                             0
# State FIPS Code                       0
# State                                 0
# County FIPS Code                      0
# County                                0
# Site Latitude                         0
# Site Longitude                        0
# dtype: int64

# %%
descriptive_stats_2024=df6.describe()
print(descriptive_stats_2024)
# Out:
#             Site ID          POC  Daily Max 1-hour NO2 Concentration  \
# count  1.390000e+03  1390.000000                         1390.000000
# mean   3.604839e+08     1.247482                           21.925540
# std    3.474502e+05     0.658809                           12.433149
# min    3.600501e+08     1.000000                            1.200000
# 25%    3.601101e+08     1.000000                           12.100000
# 50%    3.602900e+08     1.000000                           20.400000
# 75%    3.608101e+08     1.000000                           29.800000
# max    3.610300e+08     3.000000                           65.600000
#
#        Daily AQI Value  Daily Obs Count  Percent Complete  AQS Parameter Code  \
# count      1390.000000      1390.000000       1390.000000              1390.0
# mean         20.252518        23.472662         97.819424             42602.0
# std          11.722013         1.366698          5.697035                 0.0
# ...
