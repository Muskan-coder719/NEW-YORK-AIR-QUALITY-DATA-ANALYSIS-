# %%
import pandas as pd

# %%
df1=pd.read_csv('Ozone 2019.csv')
df1.shape
df1.head()
# Out:
#          Date Source    Site ID  POC  Daily Max 8-hour Ozone Concentration  \
# 0  01/01/2019    AQS  360010012    1                                 0.025
# 1  01/02/2019    AQS  360010012    1                                 0.026
# 2  01/03/2019    AQS  360010012    1                                 0.020
# 3  01/04/2019    AQS  360010012    1                                 0.019
# 4  01/05/2019    AQS  360010012    1                                 0.024
#
#   Units  Daily AQI Value Local Site Name  Daily Obs Count  Percent Complete  \
# 0   ppm               23     LOUDONVILLE               17             100.0
# 1   ppm               24     LOUDONVILLE               17             100.0
# 2   ppm               19     LOUDONVILLE               17             100.0
# 3   ppm               18     LOUDONVILLE               17             100.0
# 4   ppm               22     LOUDONVILLE               17             100.0
#
# ...

# %%
#checking for duplicates.
df1=df1.drop_duplicates()
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9843 entries, 0 to 9842
# Data columns (total 21 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Date                                  9843 non-null   object
#  1   Source                                9843 non-null   object
#  2   Site ID                               9843 non-null   int64
#  3   POC                                   9843 non-null   int64
#  4   Daily Max 8-hour Ozone Concentration  9843 non-null   float64
#  5   Units                                 9843 non-null   object
#  6   Daily AQI Value                       9843 non-null   int64
#  7   Local Site Name                       9843 non-null   object
#  8   Daily Obs Count                       9843 non-null   int64
#  9   Percent Complete                      9843 non-null   float64
#  10  AQS Parameter Code                    9843 non-null   int64
# ...

# %%
df1.shape
# Out:
# (9843, 21)

# %%
#checking for missing values.
missing_values_2019 = df1.isna().sum()
print(missing_values_2019)
# Out:
# Date                                       0
# Source                                     0
# Site ID                                    0
# POC                                        0
# Daily Max 8-hour Ozone Concentration       0
# Units                                      0
# Daily AQI Value                            0
# Local Site Name                            0
# Daily Obs Count                            0
# Percent Complete                           0
# AQS Parameter Code                         0
# AQS Parameter Description                  0
# Method Code                                0
# CBSA Code                               1318
# CBSA Name                               1318
# State FIPS Code                            0
# State                                      0
# County FIPS Code                           0
# County                                     0
# Site Latitude                              0
# Site Longitude                             0
# ...

# %%
ozone_descriptive_stats_2019=df1.describe()
print(ozone_descriptive_stats_2019)
# Out:
#             Site ID          POC  Daily Max 8-hour Ozone Concentration  \
# count  9.843000e+03  9843.000000                           9843.000000
# mean   3.606275e+08     1.110942                              0.037885
# std    3.533982e+05     0.407316                              0.010060
# min    3.600100e+08     1.000000                              0.005000
# 25%    3.603100e+08     1.000000                              0.031000
# 50%    3.606710e+08     1.000000                              0.037000
# 75%    3.609100e+08     1.000000                              0.044000
# max    3.611920e+08     3.000000                              0.085000
#
#        Daily AQI Value  Daily Obs Count  Percent Complete  AQS Parameter Code  \
# count      9843.000000      9843.000000       9843.000000              9843.0
# mean         35.733110        16.896678         99.380169             44201.0
# std          11.674042         0.575169          3.450162                 0.0
# ...

# %%
df2=pd.read_csv('Ozone 2020.csv')
print(df2.shape)
#checking for duplicates.
df2=df2.drop_duplicates()
df2.info()
# Out:
# (9672, 21)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9672 entries, 0 to 9671
# Data columns (total 21 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Date                                  9672 non-null   object
#  1   Source                                9672 non-null   object
#  2   Site ID                               9672 non-null   int64
#  3   POC                                   9672 non-null   int64
#  4   Daily Max 8-hour Ozone Concentration  9672 non-null   float64
#  5   Units                                 9672 non-null   object
#  6   Daily AQI Value                       9672 non-null   int64
#  7   Local Site Name                       9672 non-null   object
#  8   Daily Obs Count                       9672 non-null   int64
#  9   Percent Complete                      9672 non-null   float64
# ...

# %%
df2.head()
# Out:
#          Date Source    Site ID  POC  Daily Max 8-hour Ozone Concentration  \
# 0  02/01/2020    AQS  360010012    1                                 0.019
# 1  02/02/2020    AQS  360010012    1                                 0.029
# 2  02/03/2020    AQS  360010012    1                                 0.032
# 3  02/04/2020    AQS  360010012    1                                 0.031
# 4  02/05/2020    AQS  360010012    1                                 0.033
#
#   Units  Daily AQI Value Local Site Name  Daily Obs Count  Percent Complete  \
# 0   ppm               18     LOUDONVILLE               17             100.0
# 1   ppm               27     LOUDONVILLE               17             100.0
# 2   ppm               30     LOUDONVILLE               17             100.0
# 3   ppm               29     LOUDONVILLE               17             100.0
# 4   ppm               31     LOUDONVILLE               17             100.0
#
# ...

# %%
#checking for missing values.
missing_values_2020 = df2.isna().sum()
print(missing_values_2020)
# Out:
# Date                                       0
# Source                                     0
# Site ID                                    0
# POC                                        0
# Daily Max 8-hour Ozone Concentration       0
# Units                                      0
# Daily AQI Value                            0
# Local Site Name                            0
# Daily Obs Count                            0
# Percent Complete                           0
# AQS Parameter Code                         0
# AQS Parameter Description                  0
# Method Code                                0
# CBSA Code                               1342
# CBSA Name                               1342
# State FIPS Code                            0
# State                                      0
# County FIPS Code                           0
# County                                     0
# Site Latitude                              0
# Site Longitude                             0
# ...

# %%
descriptive_stats_2020=df2.describe()
print(descriptive_stats_2020)
# Out:
#             Site ID          POC  Daily Max 8-hour Ozone Concentration  \
# count  9.672000e+03  9672.000000                           9672.000000
# mean   3.606237e+08     1.091915                              0.036629
# std    3.545585e+05     0.387116                              0.010122
# min    3.600100e+08     1.000000                              0.001000
# 25%    3.603100e+08     1.000000                              0.030000
# 50%    3.606710e+08     1.000000                              0.036000
# 75%    3.609100e+08     1.000000                              0.043000
# max    3.611920e+08     3.000000                              0.082000
#
#        Daily AQI Value  Daily Obs Count  Percent Complete  AQS Parameter Code  \
# count      9672.000000      9672.000000       9672.000000              9672.0
# mean         34.468879        16.816584         98.899504             44201.0
# std          11.363804         0.766412          4.598471                 0.0
# ...

# %%
df3=pd.read_csv('Ozone 2021.csv')
print(df3.shape)
df3.info()
#checking for duplicates.
df3=df3.drop_duplicates()
# Out:
# (10240, 21)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10240 entries, 0 to 10239
# Data columns (total 21 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Date                                  10240 non-null  object
#  1   Source                                10240 non-null  object
#  2   Site ID                               10240 non-null  int64
#  3   POC                                   10240 non-null  int64
#  4   Daily Max 8-hour Ozone Concentration  10240 non-null  float64
#  5   Units                                 10240 non-null  object
#  6   Daily AQI Value                       10240 non-null  int64
#  7   Local Site Name                       10240 non-null  object
#  8   Daily Obs Count                       10240 non-null  int64
#  9   Percent Complete                      10240 non-null  float64
# ...

# %%
#checking for missing values.
missing_values_2021 = df3.isna().sum()
print(missing_values_2021)
# Out:
# Date                                       0
# Source                                     0
# Site ID                                    0
# POC                                        0
# Daily Max 8-hour Ozone Concentration       0
# Units                                      0
# Daily AQI Value                            0
# Local Site Name                            0
# Daily Obs Count                            0
# Percent Complete                           0
# AQS Parameter Code                         0
# AQS Parameter Description                  0
# Method Code                                0
# CBSA Code                               1417
# CBSA Name                               1417
# State FIPS Code                            0
# State                                      0
# County FIPS Code                           0
# County                                     0
# Site Latitude                              0
# Site Longitude                             0
# ...

# %%
descriptive_stats_2021=df3.describe()
print(descriptive_stats_2021)
# Out:
#             Site ID           POC  Daily Max 8-hour Ozone Concentration  \
# count  1.024000e+04  10240.000000                          10240.000000
# mean   3.606384e+08      1.091602                              0.037083
# std    3.579792e+05      0.390091                              0.011155
# min    3.600100e+08      1.000000                              0.001000
# 25%    3.603100e+08      1.000000                              0.030000
# 50%    3.606710e+08      1.000000                              0.036000
# 75%    3.610100e+08      1.000000                              0.043000
# max    3.611920e+08      3.000000                              0.087000
#
#        Daily AQI Value  Daily Obs Count  Percent Complete  AQS Parameter Code  \
# count     10240.000000     10240.000000      10240.000000             10240.0
# mean         35.403418        16.845508         99.073047             44201.0
# std          13.961538         0.701706          4.210235                 0.0
# ...

# %%
df4=pd.read_csv('Ozone 2022.csv')
print(df4.shape)
df4.info()
#checking for duplicates.
df4=df4.drop_duplicates()
# Out:
# (9815, 21)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9815 entries, 0 to 9814
# Data columns (total 21 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Date                                  9815 non-null   object
#  1   Source                                9815 non-null   object
#  2   Site ID                               9815 non-null   int64
#  3   POC                                   9815 non-null   int64
#  4   Daily Max 8-hour Ozone Concentration  9815 non-null   float64
#  5   Units                                 9815 non-null   object
#  6   Daily AQI Value                       9815 non-null   int64
#  7   Local Site Name                       9815 non-null   object
#  8   Daily Obs Count                       9815 non-null   int64
#  9   Percent Complete                      9815 non-null   float64
# ...

# %%
#checking for missing values.
ozone_missing_values_2021 = df3.isna().sum()
print(ozone_missing_values_2021)
# Out:
# Date                                       0
# Source                                     0
# Site ID                                    0
# POC                                        0
# Daily Max 8-hour Ozone Concentration       0
# Units                                      0
# Daily AQI Value                            0
# Local Site Name                            0
# Daily Obs Count                            0
# Percent Complete                           0
# AQS Parameter Code                         0
# AQS Parameter Description                  0
# Method Code                                0
# CBSA Code                               1417
# CBSA Name                               1417
# State FIPS Code                            0
# State                                      0
# County FIPS Code                           0
# County                                     0
# Site Latitude                              0
# Site Longitude                             0
# ...

# %%
descriptive_stats_2022=df4.describe()
print(descriptive_stats_2022)
# Out:
#             Site ID          POC  Daily Max 8-hour Ozone Concentration  \
# count  9.815000e+03  9815.000000                           9815.000000
# mean   3.606533e+08     1.095772                              0.037599
# std    3.591133e+05     0.397154                              0.010053
# min    3.600100e+08     1.000000                              0.004000
# 25%    3.603100e+08     1.000000                              0.031000
# 50%    3.606710e+08     1.000000                              0.037000
# 75%    3.610100e+08     1.000000                              0.044000
# max    3.611920e+08     3.000000                              0.085000
#
#        Daily AQI Value  Daily Obs Count  Percent Complete  AQS Parameter Code  \
# count      9815.000000      9815.000000       9815.000000              9815.0
# mean         35.477738        16.863474         99.180846             44201.0
# std          11.699340         0.663240          3.979441                 0.0
# ...

# %%
df5=pd.read_csv('Ozone 2023.csv')
print(df5.shape)
df4.info()
#checking for duplicates.
df5=df5.drop_duplicates()
# Out:
# (9746, 21)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9815 entries, 0 to 9814
# Data columns (total 21 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Date                                  9815 non-null   object
#  1   Source                                9815 non-null   object
#  2   Site ID                               9815 non-null   int64
#  3   POC                                   9815 non-null   int64
#  4   Daily Max 8-hour Ozone Concentration  9815 non-null   float64
#  5   Units                                 9815 non-null   object
#  6   Daily AQI Value                       9815 non-null   int64
#  7   Local Site Name                       9815 non-null   object
#  8   Daily Obs Count                       9815 non-null   int64
#  9   Percent Complete                      9815 non-null   float64
# ...

# %%
#checking for missing values.
missing_values_2023 = df5.isna().sum()
print(missing_values_2023)
# Out:
# Date                                       0
# Source                                     0
# Site ID                                    0
# POC                                        0
# Daily Max 8-hour Ozone Concentration       0
# Units                                      0
# Daily AQI Value                            0
# Local Site Name                            0
# Daily Obs Count                            0
# Percent Complete                           0
# AQS Parameter Code                         0
# AQS Parameter Description                  0
# Method Code                              294
# CBSA Code                               1060
# CBSA Name                               1060
# State FIPS Code                            0
# State                                      0
# County FIPS Code                           0
# County                                     0
# Site Latitude                              0
# Site Longitude                             0
# ...

# %%
descriptive_stats_2023=df5.describe()
print(descriptive_stats_2023)
# Out:
#             Site ID          POC  Daily Max 8-hour Ozone Concentration  \
# count  9.746000e+03  9746.000000                           9746.000000
# mean   3.606422e+08     1.100759                              0.037390
# std    3.649405e+05     0.403557                              0.011612
# min    3.600100e+08     1.000000                              0.000000
# 25%    3.603100e+08     1.000000                              0.030000
# 50%    3.606710e+08     1.000000                              0.037000
# 75%    3.610100e+08     1.000000                              0.045000
# max    3.611920e+08     3.000000                              0.086000
#
#        Daily AQI Value  Daily Obs Count  Percent Complete  AQS Parameter Code  \
# count      9746.000000      9746.000000       9746.000000              9746.0
# mean         35.792325        17.016725         98.924790             44201.0
# std          14.654487         1.240677          4.600376                 0.0
# ...

# %%
df6=pd.read_csv('Ozone 2024.csv')
print(df6.shape)
df4.info()
#checking for duplicates.
df6=df6.drop_duplicates()
# Out:
# (6639, 21)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9815 entries, 0 to 9814
# Data columns (total 21 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Date                                  9815 non-null   object
#  1   Source                                9815 non-null   object
#  2   Site ID                               9815 non-null   int64
#  3   POC                                   9815 non-null   int64
#  4   Daily Max 8-hour Ozone Concentration  9815 non-null   float64
#  5   Units                                 9815 non-null   object
#  6   Daily AQI Value                       9815 non-null   int64
#  7   Local Site Name                       9815 non-null   object
#  8   Daily Obs Count                       9815 non-null   int64
#  9   Percent Complete                      9815 non-null   float64
# ...

# %%
#checking for missing values.
missing_values_2024 = df6.isna().sum()
print(missing_values_2024)
# Out:
# Date                                       0
# Source                                     0
# Site ID                                    0
# POC                                        0
# Daily Max 8-hour Ozone Concentration       0
# Units                                      0
# Daily AQI Value                            0
# Local Site Name                            0
# Daily Obs Count                            0
# Percent Complete                           0
# AQS Parameter Code                         0
# AQS Parameter Description                  0
# Method Code                             2084
# CBSA Code                                651
# CBSA Name                                651
# State FIPS Code                            0
# State                                      0
# County FIPS Code                           0
# County                                     0
# Site Latitude                              0
# Site Longitude                             0
# ...

# %%
descriptive_stats_2024=df6.describe()
print(descriptive_stats_2024)
# Out:
#             Site ID          POC  Daily Max 8-hour Ozone Concentration  \
# count  6.639000e+03  6639.000000                           6639.000000
# mean   3.606497e+08     1.079379                              0.039587
# std    3.657276e+05     0.350433                              0.010872
# min    3.600100e+08     1.000000                              0.001000
# 25%    3.603100e+08     1.000000                              0.033000
# 50%    3.606710e+08     1.000000                              0.039000
# 75%    3.610100e+08     1.000000                              0.046000
# max    3.611920e+08     3.000000                              0.086000
#
#        Daily AQI Value  Daily Obs Count  Percent Complete  AQS Parameter Code  \
# count      6639.000000      6639.000000       6639.000000              6639.0
# mean         37.979666        18.889893         98.502485             44201.0
# std          14.321810         3.226288          5.104006                 0.0
# ...

# %%
fill_values_2019 = {"CBSA Code": "Unmapped", "CBSA Name": "Unknown"}
df1 = df1.fillna(fill_values_2019)

# %%
#checking for missing values.
missing_values_after_2019 = df1.isna().sum()
print(missing_values_after_2019)
# Out:
# Date                                    0
# Source                                  0
# Site ID                                 0
# POC                                     0
# Daily Max 8-hour Ozone Concentration    0
# Units                                   0
# Daily AQI Value                         0
# Local Site Name                         0
# Daily Obs Count                         0
# Percent Complete                        0
# AQS Parameter Code                      0
# AQS Parameter Description               0
# Method Code                             0
# CBSA Code                               0
# CBSA Name                               0
# State FIPS Code                         0
# State                                   0
# County FIPS Code                        0
# County                                  0
# Site Latitude                           0
# Site Longitude                          0
# dtype: int64

# %%
fill_values_2020 = {"CBSA Code": "Unmapped", "CBSA Name": "Unknown"}
df2 = df2.fillna(fill_values_2020)

# %%
#checking for missing values.
missing_values_after_2020 = df2.isna().sum()
print(missing_values_after_2020)
# Out:
# Date                                    0
# Source                                  0
# Site ID                                 0
# POC                                     0
# Daily Max 8-hour Ozone Concentration    0
# Units                                   0
# Daily AQI Value                         0
# Local Site Name                         0
# Daily Obs Count                         0
# Percent Complete                        0
# AQS Parameter Code                      0
# AQS Parameter Description               0
# Method Code                             0
# CBSA Code                               0
# CBSA Name                               0
# State FIPS Code                         0
# State                                   0
# County FIPS Code                        0
# County                                  0
# Site Latitude                           0
# Site Longitude                          0
# dtype: int64

# %%
fill_values_2021 = {"CBSA Code": "Unmapped", "CBSA Name": "Unknown"}
df3 = df3.fillna(fill_values_2021)

# %%
#checking for missing values.
missing_values_after_2021 = df3.isna().sum()
print(missing_values_after_2021)
# Out:
# Date                                    0
# Source                                  0
# Site ID                                 0
# POC                                     0
# Daily Max 8-hour Ozone Concentration    0
# Units                                   0
# Daily AQI Value                         0
# Local Site Name                         0
# Daily Obs Count                         0
# Percent Complete                        0
# AQS Parameter Code                      0
# AQS Parameter Description               0
# Method Code                             0
# CBSA Code                               0
# CBSA Name                               0
# State FIPS Code                         0
# State                                   0
# County FIPS Code                        0
# County                                  0
# Site Latitude                           0
# Site Longitude                          0
# dtype: int64

# %%
fill_values_2022 = {"CBSA Code": "Unmapped", "CBSA Name": "Unknown"}
df4 = df4.fillna(fill_values_2022)

# %%
#checking for missing values.
missing_values_after_2022 = df4.isna().sum()
print(missing_values_after_2022)
# Out:
# Date                                    0
# Source                                  0
# Site ID                                 0
# POC                                     0
# Daily Max 8-hour Ozone Concentration    0
# Units                                   0
# Daily AQI Value                         0
# Local Site Name                         0
# Daily Obs Count                         0
# Percent Complete                        0
# AQS Parameter Code                      0
# AQS Parameter Description               0
# Method Code                             0
# CBSA Code                               0
# CBSA Name                               0
# State FIPS Code                         0
# State                                   0
# County FIPS Code                        0
# County                                  0
# Site Latitude                           0
# Site Longitude                          0
# dtype: int64

# %%
fill_values_2023 = {"CBSA Code": "Unmapped", "CBSA Name": "Unknown","Method Code":'Missing'}
df5 = df5.fillna(fill_values_2023)

# %%
#checking for missing values.
missing_values_after_2023 = df5.isna().sum()
print(missing_values_after_2023)
# Out:
# Date                                    0
# Source                                  0
# Site ID                                 0
# POC                                     0
# Daily Max 8-hour Ozone Concentration    0
# Units                                   0
# Daily AQI Value                         0
# Local Site Name                         0
# Daily Obs Count                         0
# Percent Complete                        0
# AQS Parameter Code                      0
# AQS Parameter Description               0
# Method Code                             0
# CBSA Code                               0
# CBSA Name                               0
# State FIPS Code                         0
# State                                   0
# County FIPS Code                        0
# County                                  0
# Site Latitude                           0
# Site Longitude                          0
# dtype: int64

# %%
fill_values_2024 = {"CBSA Code": "Unmapped", "CBSA Name": "Unknown","Method Code":'Missing'}
df6 = df6.fillna(fill_values_2024)

# %%
#checking for missing values.
missing_values_after_2024 = df6.isna().sum()
print(missing_values_after_2024)
# Out:
# Date                                    0
# Source                                  0
# Site ID                                 0
# POC                                     0
# Daily Max 8-hour Ozone Concentration    0
# Units                                   0
# Daily AQI Value                         0
# Local Site Name                         0
# Daily Obs Count                         0
# Percent Complete                        0
# AQS Parameter Code                      0
# AQS Parameter Description               0
# Method Code                             0
# CBSA Code                               0
# CBSA Name                               0
# State FIPS Code                         0
# State                                   0
# County FIPS Code                        0
# County                                  0
# Site Latitude                           0
# Site Longitude                          0
# dtype: int64

# %%
df1.to_csv('ozone_2019_cleaned_data.csv', index=False)
df2.to_csv('ozone_2020_cleaned_data.csv', index=False)
df3.to_csv('ozone_2021_cleaned_data.csv', index=False)
df4.to_csv('ozone_2022_cleaned_data.csv', index=False)
df5.to_csv('ozone_2023_cleaned_data.csv', index=False)
df6.to_csv('ozone_2024_cleaned_data.csv', index=False)
